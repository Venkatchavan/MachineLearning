# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Set 1

# %%
df = pd.read_csv('/content/drive/MyDrive/Assignment-Data Science/2.Stats-2/data/company.csv')

# %%
df
# Out:
#       Name of company Measure X       X
# 0       Allied Signal    24.23%  0.2423
# 1       Bankers Trust    25.53%  0.2553
# 2       General Mills    25.41%  0.2541
# 3      ITT Industries    24.14%  0.2414
# 4   J.P. Morgan & Co.    29.62%  0.2962
# 5     Lehman Brothers    28.25%  0.2825
# 6            Marriott    25.81%  0.2581
# 7                 MCI    24.39%  0.2439
# 8       Merrill Lynch    40.26%  0.4026
# 9           Microsoft    32.95%  0.3295
# 10     Morgan Stanley    91.36%  0.9136
# 11   Sun Microsystems    25.99%  0.2599
# 12          Travelers    39.42%  0.3942
# 13         US Airways    26.71%  0.2671
# 14     Warner-Lambert       35%  0.3500

# %%
plt.boxplot(df['X'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f95f2da2290>,
#   <matplotlib.lines.Line2D at 0x7f95f2da2530>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f95f2da27d0>,
#   <matplotlib.lines.Line2D at 0x7f95f2da2a70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f95f2da1ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f95f2da2d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f95f2da2fb0>],
#  'means': []}

# %%
df['X'].describe()
# Out:
# count    15.000000
# mean      0.332713
# std       0.169454
# min       0.241400
# 25%       0.254700
# 50%       0.267100
# 75%       0.339750
# max       0.913600
# Name: X, dtype: float64

# %% [markdown]
# # Set 2

# %%
from scipy import stats
from scipy.stats import norm
# Find Z-Scores at X=50; Z = (X - µ) / σ
Z=(50-45)/8
Z
# Out:
# 0.625

# %% [markdown]
# ### Q1

# %%
# Find probability P(X>50) = 1-stats.norm.cdf(abs(z_score))
1-stats.norm.cdf(abs(0.625))
# Out:
# 0.26598552904870054

# %% [markdown]
# ### Q4

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# ### Q5

# %%
Mean = 5+7
print('Mean Profit is Rs', Mean*45,'Million')
# Out:
# Mean Profit is Rs 540 Million

# %%
SD = np.sqrt((9)+(16))
print('Standard Deviation is Rs', SD*45, 'Million')
# Out:
# Standard Deviation is Rs 225.0 Million

# %%
#A
print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %%
#B
X= 540+(-1.645)*(225)
print('5th percentile of profit (in Million Rupees) is',np.round(X,))
# Out:
# 5th percentile of profit (in Million Rupees) is 170.0

# %%
#C
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086
