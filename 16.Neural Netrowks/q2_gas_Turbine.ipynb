# %% [markdown]
# ## Predicting turbine energy yield (TEY) using ambient variables as features.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
tf.debugging.set_log_device_placement(False)
import warnings
warnings.filterwarnings('ignore')

# %%
# Generating reproducible results from same code
tf.random.set_seed(14)

# %%
raw = pd.read_csv("/content/drive/MyDrive/Assignment-Data Science/16.Neural Netrowks/data_set/gas_turbines.csv")
raw.head()
#TEY is the variable we should predict.
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df = raw.copy()
df = df.drop(['AFDP','GTEP','TIT','TAT','CDP','CO','NOX'],axis=1)
df.head()
# Out:
#        AT      AP      AH     TEY
# 0  6.8594  1007.9  96.799  114.70
# 1  6.7850  1008.4  97.118  114.72
# 2  6.8977  1008.8  95.939  114.71
# 3  7.0569  1009.2  95.249  114.72
# 4  7.3978  1009.7  95.150  114.72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   TEY     15039 non-null  float64
# dtypes: float64(4)
# memory usage: 470.1 KB

# %%
df.describe()
# Out:
#                  AT           AP            AH           TEY
# count  15039.000000  15039.00000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174    134.188464
# std        7.574323      6.41076     13.793439     15.829717
# min        0.522300    985.85000     30.344000    100.170000
# 25%       11.408000   1008.90000     69.750000    127.985000
# 50%       18.186000   1012.80000     82.266000    133.780000
# 75%       23.862500   1016.90000     90.043500    140.895000
# max       34.929000   1034.20000    100.200000    174.610000

# %% [markdown]
# # Feature Analysis

# %% [markdown]
#  All features in the dataset can be used in model building. This is a Regression Problem.

# %% [markdown]
# # Train | Split dataset

# %%
X =df.iloc[:,:-1]
Y = df.iloc[:,-1]


X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3)

# %% [markdown]
# A common mistake when configuring a neural network is to first normalize the data before splitting the data.

# %%
y_train=np.reshape(y_train.to_numpy(), (-1,1))
y_test=np.reshape(y_test.to_numpy(), (-1,1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

print(scaler_x.fit(X_train))
xtrain_scale=scaler_x.transform(X_train)

print(scaler_x.fit(X_test))
xtest_scale=scaler_x.transform(X_test)

print(scaler_y.fit(y_train))
ytrain_scale=scaler_y.transform(y_train)

print(scaler_y.fit(y_test))
ytest_scale=scaler_y.transform(y_test)
# Out:
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()

# %%
len(xtrain_scale)
# Out:
# 10527

# %% [markdown]
# # Neural Network Modelling

# %% [markdown]
# ### Building the Model

# %%
# create model
model1 = Sequential()
model1.add(Dense(4, input_dim=3, kernel_initializer='normal', activation='relu'))
model1.add(Dense(2106,kernel_initializer='normal', activation='relu'))
model1.add(Dense(1, activation='linear'))
# Compile model
model1.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse','mae'])
# Fit the model
hist1 = model1.fit(xtrain_scale, ytrain_scale, validation_split=0.33, epochs=100, batch_size=150)
#At epoch 50, mse and mae just keeps oscillating back and forth
# Out:
# Epoch 1/100
# 48/48 [==============================] - 2s 13ms/step - loss: 0.0723 - mse: 0.0723 - mae: 0.2066 - val_loss: 0.0484 - val_mse: 0.0484 - val_mae: 0.1602
# Epoch 2/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0468 - mse: 0.0468 - mae: 0.1549 - val_loss: 0.0467 - val_mse: 0.0467 - val_mae: 0.1553
# Epoch 3/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0455 - mse: 0.0455 - mae: 0.1546 - val_loss: 0.0450 - val_mse: 0.0450 - val_mae: 0.1524
# Epoch 4/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0435 - mse: 0.0435 - mae: 0.1521 - val_loss: 0.0437 - val_mse: 0.0437 - val_mae: 0.1549
# Epoch 5/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0420 - mse: 0.0420 - mae: 0.1543 - val_loss: 0.0425 - val_mse: 0.0425 - val_mae: 0.1590
# Epoch 6/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1582 - val_loss: 0.0429 - val_mse: 0.0429 - val_mae: 0.1603
# Epoch 7/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1585 - val_loss: 0.0421 - val_mse: 0.0421 - val_mae: 0.1630
# Epoch 8/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1620 - val_loss: 0.0435 - val_mse: 0.0435 - val_mae: 0.1610
# Epoch 9/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1582 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1618
# Epoch 10/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1604 - val_loss: 0.0435 - val_mse: 0.0435 - val_mae: 0.1622
# Epoch 11/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1595 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1617
# Epoch 12/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1597 - val_loss: 0.0419 - val_mse: 0.0419 - val_mae: 0.1599
# Epoch 13/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1581 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1603
# Epoch 14/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0406 - mse: 0.0406 - mae: 0.1579 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1658
# Epoch 15/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0404 - mse: 0.0404 - mae: 0.1597 - val_loss: 0.0411 - val_mse: 0.0411 - val_mae: 0.1602
# Epoch 16/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1586 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1604
# Epoch 17/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1587 - val_loss: 0.0427 - val_mse: 0.0427 - val_mae: 0.1675
# Epoch 18/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1615 - val_loss: 0.0408 - val_mse: 0.0408 - val_mae: 0.1594
# Epoch 19/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1570 - val_loss: 0.0408 - val_mse: 0.0408 - val_mae: 0.1605
# Epoch 20/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1592 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1608
# Epoch 21/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1586 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1616
# Epoch 22/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1571 - val_loss: 0.0409 - val_mse: 0.0409 - val_mae: 0.1584
# Epoch 23/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1589 - val_loss: 0.0405 - val_mse: 0.0405 - val_mae: 0.1594
# Epoch 24/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1569 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1632
# Epoch 25/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1577 - val_loss: 0.0405 - val_mse: 0.0405 - val_mae: 0.1577
# Epoch 26/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1562 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1579
# Epoch 27/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1576 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1588
# Epoch 28/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1565 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1575
# Epoch 29/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1563 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1586
# Epoch 30/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1569 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1582
# Epoch 31/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1559 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1581
# Epoch 32/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1565 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1646
# Epoch 33/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1574 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1592
# Epoch 34/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1569 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1587
# Epoch 35/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1567 - val_loss: 0.0405 - val_mse: 0.0405 - val_mae: 0.1604
# Epoch 36/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1560 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1652
# Epoch 37/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1588 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1581
# Epoch 38/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1565 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1579
# Epoch 39/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1567 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1606
# Epoch 40/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1570 - val_loss: 0.0448 - val_mse: 0.0448 - val_mae: 0.1689
# Epoch 41/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1588 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1576
# Epoch 42/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1562 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1585
# Epoch 43/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1571 - val_loss: 0.0409 - val_mse: 0.0409 - val_mae: 0.1597
# Epoch 44/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1581 - val_loss: 0.0410 - val_mse: 0.0410 - val_mae: 0.1600
# Epoch 45/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1578 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1575
# Epoch 46/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1556 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1581
# Epoch 47/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1568 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1579
# Epoch 48/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1581 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1582
# Epoch 49/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1555 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1582
# Epoch 50/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1576 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1577
# Epoch 51/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1555 - val_loss: 0.0425 - val_mse: 0.0425 - val_mae: 0.1637
# Epoch 52/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1583 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1575
# Epoch 53/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1562 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1584
# Epoch 54/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1560 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1575
# Epoch 55/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1559 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1576
# Epoch 56/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1558 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1576
# Epoch 57/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1559 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1601
# Epoch 58/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1570 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1579
# Epoch 59/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1565 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1578
# Epoch 60/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1574 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1577
# Epoch 61/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1550 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1589
# Epoch 62/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1562 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1590
# Epoch 63/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1577 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1581
# Epoch 64/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1558 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1573
# Epoch 65/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1560 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1583
# Epoch 66/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1558 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1609
# Epoch 67/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1561 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1588
# Epoch 68/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1572 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1576
# Epoch 69/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1580 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1587
# Epoch 70/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1555 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1589
# Epoch 71/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1550 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1586
# Epoch 72/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1565 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1576
# Epoch 73/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1571 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1583
# Epoch 74/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1557 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1579
# Epoch 75/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1558 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1570
# Epoch 76/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1550 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1577
# Epoch 77/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1563 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1564
# Epoch 78/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1556 - val_loss: 0.0397 - val_mse: 0.0397 - val_mae: 0.1570
# Epoch 79/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1541 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1590
# Epoch 80/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1563 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1582
# Epoch 81/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1571 - val_loss: 0.0397 - val_mse: 0.0397 - val_mae: 0.1581
# Epoch 82/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1551 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1596
# Epoch 83/100
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1560 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1589
# Epoch 84/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1560 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1562
# Epoch 85/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1546 - val_loss: 0.0405 - val_mse: 0.0405 - val_mae: 0.1600
# Epoch 86/100
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1580 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1566
# Epoch 87/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1562 - val_loss: 0.0403 - val_mse: 0.0403 - val_mae: 0.1587
# Epoch 88/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1548 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1576
# Epoch 89/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1553 - val_loss: 0.0395 - val_mse: 0.0395 - val_mae: 0.1568
# Epoch 90/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1562 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1561
# Epoch 91/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1555 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1557
# Epoch 92/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1543 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1564
# Epoch 93/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1544 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1578
# Epoch 94/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1547 - val_loss: 0.0393 - val_mse: 0.0393 - val_mae: 0.1560
# Epoch 95/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1544 - val_loss: 0.0395 - val_mse: 0.0395 - val_mae: 0.1570
# Epoch 96/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0381 - mse: 0.0381 - mae: 0.1542 - val_loss: 0.0393 - val_mse: 0.0393 - val_mae: 0.1555
# Epoch 97/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1546 - val_loss: 0.0393 - val_mse: 0.0393 - val_mae: 0.1560
# Epoch 98/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1540 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1585
# Epoch 99/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1551 - val_loss: 0.0392 - val_mse: 0.0392 - val_mae: 0.1558
# Epoch 100/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1537 - val_loss: 0.0392 - val_mse: 0.0392 - val_mae: 0.1558

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 2106)              10530
#
#  dense_2 (Dense)             (None, 1)                 2107
#
# =================================================================
# Total params: 12,653
# Trainable params: 12,653
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Evaluation

# %%
y_predict = model1.predict(xtest_scale)
# Out:
# 141/141 [==============================] - 0s 1ms/step

# %%
print(hist1.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
hist1_df = pd.DataFrame(hist1.history)
hist1_df["epoch"]=hist1.epoch
hist1_df.tail()
# Out:
#         loss       mse       mae  val_loss   val_mse   val_mae  epoch
# 95  0.038126  0.038126  0.154198  0.039292  0.039292  0.155508     95
# 96  0.038707  0.038707  0.154563  0.039261  0.039261  0.156022     96
# 97  0.038314  0.038314  0.153991  0.040105  0.040105  0.158482     97
# 98  0.038684  0.038684  0.155085  0.039181  0.039181  0.155822     98
# 99  0.038233  0.038233  0.153724  0.039196  0.039196  0.155789     99

# %% [markdown]
# # Visualize Training History

# %%
# summarize history for Loss

sns.set(rc={'figure.figsize':(6,4)})

plt.plot(hist1.history['loss'])
plt.plot(hist1.history['val_loss'])
plt.title('model1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist1.history['mse'])
plt.plot(hist1.history['val_mse'])
plt.title('model1 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
